# %%
from datetime import datetime
import xmltodict
import pickle
import xml.etree.ElementTree as xml
import os

# %% [markdown]
# ## 1 Obtendo dados dos arquivos xml
#
# Temos muitas informações relevantes para analizar o negócio armazenadas localmente em forma de `.xml`s que podemos transformar em dados tabulares.
#
# ### 1.1 Notas de vendas
#
# A primeira fonte de dados que vamos explorar são as notas de vendas. Vamos começar com um gerador que nos entregará o nome dos arquivos relevantes:

# %%
PASTA_VENDAS = r"C:\GDOOR Sistemas\GDOOR SLIM\NFCe\XML\Vendas"
nfes = [os.path.join(PASTA_VENDAS, filename) for filename in os.listdir(PASTA_VENDAS) if len(filename) > 10]

# %%
def get_pay(xml: dict):
    """return the payment section of the `xml`"""
    try:
        pag = xml["NFe"]["infNFe"]["total"]["ICMSTot"]["pag"]
    except KeyError:
        try:
            pag = xml["nfeProc"]["NFe"]["infNFe"]["pag"]
        except KeyError:
            pag = xml["NFe"]["infNFe"]["pag"]
    if type(pag["detPag"]) is list:
        return {
            "type": ";".join([x["tPag"] for x in pag["detPag"]]),
            "amount": ";".join([x["vPag"] for x in pag["detPag"]])}
    else:
        return {
            "type": pag["detPag"]["tPag"],
            "amount": pag["detPag"]["vPag"]}

incs = []
_ls = []
for nf in nfes:
    with open(nf) as doc:
        xmlelem = xmltodict.parse(doc.read())
    try:
        _ls.append(get_pay(xmlelem))
    except KeyError:
        incs.append(xmlelem)

len(incs)
# Out:
# 0

# %%
[a for a in _ls if len(a["type"]) > 2]
# Out:
# [{'type': '01;04', 'amount': '35.50;54.28'},
#  {'type': '03;99', 'amount': '270.00;1.38'},
#  {'type': '01;04', 'amount': '190.00;24.50'},
#  {'type': '03;01', 'amount': '60.00;2.00'},
#  {'type': '01;99', 'amount': '50.00;72.47'},
#  {'type': '01;99', 'amount': '0.20;45.00'},
#  {'type': '01;01', 'amount': '4.00;7898286201937.00'},
#  {'type': '01;99', 'amount': '30.00;120.40'},
#  {'type': '99;01', 'amount': '154.50;0.03'},
#  {'type': '99;01', 'amount': '50.00;0.20'},
#  {'type': '01;99', 'amount': '10.00;24.50'},
#  {'type': '01;99', 'amount': '4.00;44.70'},
#  {'type': '01;99', 'amount': '0.03;146.20'},
#  {'type': '01;99', 'amount': '0.04;124.20'},
#  {'type': '01;99', 'amount': '40.00;11.80'},
#  {'type': '01;99', 'amount': '0.03;78.30'},
#  {'type': '01;99', 'amount': '0.02;22.90'},
#  {'type': '01;01', 'amount': '2.00;7896098900109.00'},
#  {'type': '01;99', 'amount': '60.00;137.60'},
#  {'type': '99;01', 'amount': '20.20;20.00'},
#  {'type': '01;99', 'amount': '30.00;139.71'},
#  {'type': '99;01', 'amount': '6.00;20.00'},
#  {'type': '01;99', 'amount': '5.50;29.90'},
#  {'type': '01;99', 'amount': '50.00;47.14'},
#  {'type': '01;99', 'amount': '40.00;29.03'},
#  {'type': '01;99', 'amount': '20.00;120.00'},
#  {'type': '01;99', 'amount': '100.00;48.62'},
#  {'type': '01;99', 'amount': '14.30;19.00'},
#  {'type': '99;01', 'amount': '1.10;4.00'},
#  {'type': '01;99', 'amount': '3.30;27.70'},
#  {'type': '01;99', 'amount': '12.00;12.40'},
#  {'type': '01;99', 'amount': '20.00;9.50'},
#  {'type': '01;99', 'amount': '50.00;3.10'},
#  {'type': '01;99', 'amount': '21.00;126.60'},
#  {'type': '01;99', 'amount': '30.00;10.30'},
#  {'type': '01;99', 'amount': '5.50;5.00'},
#  {'type': '01;99', 'amount': '25.00;17.50'},
#  {'type': '01;99', 'amount': '1.00;70.00'},
#  {'type': '99;01', 'amount': '14.00;11.00'},
#  {'type': '01;99', 'amount': '50.00;12.42'},
#  {'type': '01;99', 'amount': '14.38;20.00'},
#  {'type': '01;99', 'amount': '20.00;169.00'},
#  {'type': '01;99', 'amount': '1.50;51.30'},
#  {'type': '99;01', 'amount': '7.10;100.00'},
#  {'type': '01;99', 'amount': '8.95;40.00'},
#  {'type': '01;99', 'amount': '2.00;33.38'},
#  {'type': '05;01', 'amount': '12.00;20.00'},
#  {'type': '05;01', 'amount': '2.90;20.00'},
#  {'type': '03;01', 'amount': '95.00;55.00'},
#  {'type': '01;05', 'amount': '50.00;40.50'},
#  {'type': '01;05', 'amount': '10.00;41.10'},
#  {'type': '01;05', 'amount': '70.00;235.63'},
#  {'type': '01;05', 'amount': '50.00;76.61'},
#  {'type': '04;01', 'amount': '100.00;5.00'},
#  {'type': '01;05', 'amount': '20.00;22.50'},
#  {'type': '05;01', 'amount': '100.00;1.20'},
#  {'type': '01;05', 'amount': '225.00;72.57'},
#  {'type': '01;05', 'amount': '0.40;26.00'},
#  {'type': '01;05', 'amount': '100.00;31.80'},
#  {'type': '05;01', 'amount': '150.00;8.00'},
#  {'type': '01;05', 'amount': '16.00;25.78'},
#  {'type': '05;01', 'amount': '6.35;10.00'},
#  {'type': '01;05', 'amount': '100.00;56.66'},
#  {'type': '01;05', 'amount': '170.00;672.00'},
#  {'type': '04;05', 'amount': '50.00;52.00'},
#  {'type': '01;05', 'amount': '10.00;3.80'},
#  {'type': '01;05', 'amount': '20.00;80.00'},
#  {'type': '01;05', 'amount': '200.00;37.58'},
#  {'type': '01;05', 'amount': '30.00;33.75'},
#  {'type': '01;05', 'amount': '0.76;50.00'},
#  {'type': '01;05', 'amount': '60.00;44.35'},
#  {'type': '01;05', 'amount': '3.00;15.00'},
#  {'type': '01;05', 'amount': '70.00;5.67'},
#  {'type': '01;05', 'amount': '2.80;4.80'},
#  {'type': '01;05', 'amount': '10.00;8.00'},
#  {'type': '01;05', 'amount': '18.34;170.00'},
#  {'type': '01;05', 'amount': '79.00;34.20'},
#  {'type': '05;01', 'amount': '9.80;4.00'},
#  {'type': '01;05', 'amount': '100.00;15.58'},
#  {'type': '01;05', 'amount': '50.00;40.76'},
#  {'type': '01;05', 'amount': '10.00;17.80'},
#  {'type': '01;05', 'amount': '100.00;14.95'},
#  {'type': '01;05', 'amount': '30.00;69.70'},
#  {'type': '05;01', 'amount': '250.00;2.00'},
#  {'type': '01;05', 'amount': '80.00;37.80'},
#  {'type': '01;05', 'amount': '150.00;140.00'},
#  {'type': '01;05', 'amount': '50.00;108.01'},
#  {'type': '01;05', 'amount': '50.00;98.60'},
#  {'type': '01;05', 'amount': '100.00;70.08'},
#  {'type': '01;05', 'amount': '20.00;22.50'},
#  {'type': '05;01', 'amount': '13.80;0.50'},
#  {'type': '01;05', 'amount': '0.90;50.00'},
#  {'type': '05;01', 'amount': '0.80;4.00'},
#  {'type': '01;05', 'amount': '60.00;96.50'},
#  {'type': '01;05', 'amount': '25.00;30.00'},
#  {'type': '01;05', 'amount': '25.00;8.00'},
#  {'type': '01;05', 'amount': '20.00;40.30'},
#  {'type': '01;05', 'amount': '20.00;12.00'},
#  {'type': '01;05', 'amount': '50.00;59.70'},
#  {'type': '05;01', 'amount': '35.00;6.00'},
#  {'type': '01;05', 'amount': '21.00;70.87'},
#  {'type': '01;05', 'amount': '0.20;28.00'},
#  {'type': '01;05', 'amount': '100.00;74.56'},
#  {'type': '01;05', 'amount': '65.50;14.50'},
#  {'type': '01;05', 'amount': '0.44;40.00'},
#  {'type': '05;01', 'amount': '5.90;20.00'},
#  {'type': '01;05', 'amount': '74.00;76.43'},
#  {'type': '17;05', 'amount': '12.00;0.40'},
#  {'type': '01;05', 'amount': '55.70;65.28'},
#  {'type': '01;05', 'amount': '50.00;37.79'},
#  {'type': '05;01', 'amount': '45.00;100.00'},
#  {'type': '05;01', 'amount': '15.00;9.50'},
#  {'type': '05;01', 'amount': '40.00;21.30'},
#  {'type': '01;05', 'amount': '100.00;66.73'},
#  {'type': '01;05', 'amount': '40.00;32.76'},
#  {'type': '05;01', 'amount': '50.00;10.00'},
#  {'type': '01;05', 'amount': '30.00;39.97'},
#  {'type': '01;05', 'amount': '50.00;100.32'},
#  {'type': '05;01', 'amount': '90.00;1.13'},
#  {'type': '01;05', 'amount': '100.00;1.70'},
#  {'type': '01;05', 'amount': '4.97;38.50'},
#  {'type': '01;05', 'amount': '22.00;2.80'},
#  {'type': '05;03', 'amount': '25.00;45.00'},
#  {'type': '01;05', 'amount': '24.00;27.80'},
#  {'type': '01;05', 'amount': '50.00;85.20'},
#  {'type': '01;05', 'amount': '7.00;30.00'},
#  {'type': '01;05', 'amount': '10.00;11.70'},
#  {'type': '01;05', 'amount': '50.00;34.00'},
#  {'type': '01;05', 'amount': '31.50;44.80'},
#  {'type': '01;05', 'amount': '100.00;11.75'},
#  {'type': '01;05', 'amount': '40.00;43.45'},
#  {'type': '01;05', 'amount': '100.00;189.10'},
#  {'type': '01;05', 'amount': '10.00;54.77'},
#  {'type': '01;05', 'amount': '20.00;11.84'},
#  {'type': '01;05', 'amount': '20.00;73.87'},
#  {'type': '01;05', 'amount': '30.00;81.50'},
#  {'type': '01;05', 'amount': '52.60;54.40'},
#  {'type': '01;05', 'amount': '67.00;124.30'},
#  {'type': '01;05', 'amount': '10.00;93.60'},
#  {'type': '01;05', 'amount': '3.90;80.20'},
#  {'type': '01;05', 'amount': '1.50;88.50'},
#  {'type': '01;05', 'amount': '6.00;170.75'},
#  {'type': '01;05', 'amount': '50.00;18.00'},
#  {'type': '01;05', 'amount': '50.00;35.20'},
#  {'type': '01;05', 'amount': '6.24;100.00'},
#  {'type': '01;05', 'amount': '5.00;2.00'},
#  {'type': '05;01', 'amount': '101.43;50.00'},
#  {'type': '01;05', 'amount': '20.00;87.39'},
#  {'type': '05;03', 'amount': '10.30;10.00'},
#  {'type': '01;05', 'amount': '8.00;23.43'},
#  {'type': '01;05', 'amount': '100.00;43.50'},
#  {'type': '05;01', 'amount': '123.57;100.00'},
#  {'type': '01;05', 'amount': '10.00;47.90'},
#  {'type': '01;05', 'amount': '5.00;14.50'},
#  {'type': '01;05', 'amount': '40.00;123.91'},
#  {'type': '01;05', 'amount': '4.00;20.00'},
#  {'type': '01;05', 'amount': '5.00;0.80'},
#  {'type': '05;01', 'amount': '10.00;20.00'},
#  {'type': '01;05', 'amount': '74.50;90.19'},
#  {'type': '05;01', 'amount': '13.00;0.30'},
#  {'type': '01;05', 'amount': '100.00;3.34'},
#  {'type': '01;05', 'amount': '30.00;4.20'},
#  {'type': '01;05', 'amount': '300.00;53.10'},
#  {'type': '01;05', 'amount': '150.00;323.50'},
#  {'type': '01;05', 'amount': '70.00;91.91'},
#  {'type': '01;05', 'amount': '50.00;103.67'},
#  {'type': '01;05', 'amount': '30.00;62.40'},
#  {'type': '01;05', 'amount': '158.00;62.52'},
#  {'type': '01;05', 'amount': '20.50;188.15'},
#  {'type': '01;05', 'amount': '0.50;85.29'},
#  {'type': '01;05', 'amount': '10.00;50.00'},
#  {'type': '01;05', 'amount': '100.00;42.95'},
#  {'type': '01;05', 'amount': '130.00;13.40'},
#  {'type': '01;05', 'amount': '100.00;0.38'},
#  {'type': '01;05', 'amount': '0.26;47.00'},
#  {'type': '01;05', 'amount': '80.00;7.30'},
#  {'type': '01;05', 'amount': '250.00;83.33'},
#  {'type': '01;05', 'amount': '8.00;1.30'},
#  {'type': '01;05', 'amount': '50.00;2.00'},
#  {'type': '01;05', 'amount': '300.00;23.99'},
#  {'type': '01;05', 'amount': '39.50;20.00'},
#  {'type': '01;05', 'amount': '100.00;13.79'},
#  {'type': '01;05', 'amount': '2.50;10.00'},
#  {'type': '01;05', 'amount': '10.80;171.50'},
#  {'type': '05;01', 'amount': '12.00;0.89'},
#  {'type': '01;05', 'amount': '2.40;30.00'},
#  {'type': '01;05', 'amount': '90.00;47.67'},
#  {'type': '01;05', 'amount': '30.00;22.00'},
#  {'type': '01;05', 'amount': '25.00;3.37'},
#  {'type': '01;05', 'amount': '21.00;95.50'},
#  {'type': '01;05', 'amount': '20.00;1.87'},
#  {'type': '01;05', 'amount': '25.00;152.25'},
#  {'type': '01;05', 'amount': '150.00;147.24'},
#  {'type': '01;05', 'amount': '30.00;30.20'},
#  {'type': '01;05', 'amount': '40.00;31.25'},
#  {'type': '01;05', 'amount': '60.00;35.52'},
#  {'type': '01;05', 'amount': '100.00;23.68'},
#  {'type': '01;05', 'amount': '20.00;26.50'},
#  {'type': '01;05', 'amount': '100.00;3.34'},
#  {'type': '01;05', 'amount': '50.00;26.90'},
#  {'type': '01;05', 'amount': '50.00;1.27'},
#  {'type': '01;05', 'amount': '91.50;64.38'},
#  {'type': '01;05', 'amount': '30.00;115.82'},
#  {'type': '01;05', 'amount': '12.35;4.65'},
#  {'type': '01;05', 'amount': '100.00;46.60'},
#  {'type': '01;05', 'amount': '60.00;59.70'},
#  {'type': '01;05', 'amount': '20.00;46.80'},
#  {'type': '01;05', 'amount': '70.00;3.18'},
#  {'type': '01;05', 'amount': '46.70;90.68'},
#  {'type': '01;05', 'amount': '0.25;25.00'},
#  {'type': '03;01', 'amount': '50.00;8.50'},
#  {'type': '01;05', 'amount': '20.00;24.30'},
#  {'type': '01;05', 'amount': '2.24;60.00'},
#  {'type': '01;05', 'amount': '1.70;28.08'},
#  {'type': '05;01', 'amount': '30.00;0.50'},
#  {'type': '01;05', 'amount': '20.00;22.50'},
#  {'type': '01;05', 'amount': '60.00;3.26'},
#  {'type': '01;05', 'amount': '70.00;14.89'},
#  {'type': '01;05', 'amount': '300.00;156.38'},
#  {'type': '01;05', 'amount': '100.00;113.27'},
#  {'type': '05;01', 'amount': '22.00;2.10'},
#  {'type': '01;05', 'amount': '72.00;93.07'},
#  {'type': '01;05', 'amount': '140.00;45.31'},
#  {'type': '01;05', 'amount': '50.00;10.90'},
#  {'type': '01;05', 'amount': '5.00;5.50'},
#  {'type': '01;05', 'amount': '4.55;60.00'},
#  {'type': '01;05', 'amount': '140.00;39.02'},
#  {'type': '01;05', 'amount': '26.00;8.50'},
#  {'type': '01;05', 'amount': '20.00;33.75'},
#  {'type': '01;05', 'amount': '90.00;1.35'},
#  {'type': '01;03;05', 'amount': '20.00;30.00;178.40'},
#  {'type': '05;01', 'amount': '70.00;0.47'},
#  {'type': '01;05', 'amount': '100.00;15.27'},
#  {'type': '05;01', 'amount': '160.00;223.60'},
#  {'type': '01;05', 'amount': '10.00;51.50'},
#  {'type': '01;05', 'amount': '50.00;21.50'},
#  {'type': '01;05', 'amount': '100.00;12.36'},
#  {'type': '01;05', 'amount': '400.00;11.40'},
#  {'type': '01;05', 'amount': '50.00;48.62'},
#  {'type': '01;05', 'amount': '4.00;1.00'},
#  {'type': '05;01', 'amount': '80.00;5.79'},
#  {'type': '01;05', 'amount': '20.00;14.99'},
#  {'type': '01;05', 'amount': '20.00;40.48'},
#  {'type': '01;05', 'amount': '100.00;36.46'},
#  {'type': '01;05', 'amount': '10.00;88.10'},
#  {'type': '01;05', 'amount': '200.00;351.48'},
#  {'type': '01;05', 'amount': '30.00;11.20'},
#  {'type': '05;01', 'amount': '25.00;33.30'},
#  {'type': '01;05', 'amount': '50.00;74.09'},
#  {'type': '01;05', 'amount': '100.00;191.22'},
#  {'type': '01;05', 'amount': '40.00;94.90'},
#  {'type': '01;05', 'amount': '60.00;127.59'},
#  {'type': '01;05', 'amount': '42.00;72.00'},
#  {'type': '01;05', 'amount': '100.00;80.00'},
#  {'type': '01;05', 'amount': '20.00;88.34'},
#  {'type': '01;05', 'amount': '8.30;2.20'},
#  {'type': '01;05', 'amount': '65.00;47.00'},
#  {'type': '01;05', 'amount': '300.00;22.15'},
#  {'type': '01;05', 'amount': '50.00;24.90'},
#  {'type': '01;05', 'amount': '100.00;4.38'},
#  {'type': '01;05', 'amount': '50.00;14.10'},
#  {'type': '01;05', 'amount': '36.00;30.00'},
#  {'type': '01;05', 'amount': '14.00;48.20'},
#  {'type': '01;05', 'amount': '20.00;100.77'},
#  {'type': '01;05', 'amount': '200.00;267.39'},
#  {'type': '01;05', 'amount': '100.00;55.40'},
#  {'type': '01;05', 'amount': '300.00;82.59'},
#  {'type': '01;05', 'amount': '400.00;34.53'},
#  {'type': '01;05', 'amount': '40.00;14.50'},
#  {'type': '01;05', 'amount': '70.00;56.90'},
#  {'type': '01;05', 'amount': '7.00;4.12'},
#  {'type': '01;05', 'amount': '67.00;9.50'},
#  {'type': '01;05', 'amount': '40.00;15.40'},
#  {'type': '01;05', 'amount': '100.00;16.61'},
#  {'type': '01;05', 'amount': '30.00;8.40'},
#  {'type': '01;05', 'amount': '50.00;35.00'},
#  {'type': '01;05', 'amount': '100.00;58.15'},
#  {'type': '01;05', 'amount': '120.00;63.74'},
#  {'type': '01;05', 'amount': '7.00;79.60'},
#  {'type': '01;05', 'amount': '8.00;421.01'},
#  {'type': '01;05', 'amount': '50.00;269.64'},
#  {'type': '01;05', 'amount': '40.00;5.50'},
#  {'type': '01;05', 'amount': '20.00;4.00'},
#  {'type': '01;05', 'amount': '94.00;123.00'},
#  {'type': '01;05', 'amount': '100.00;23.40'},
#  {'type': '01;05', 'amount': '8.90;31.00'},
#  {'type': '01;05', 'amount': '20.00;5.50'},
#  {'type': '05;01', 'amount': '50.00;0.26'},
#  {'type': '01;05', 'amount': '40.00;128.88'},
#  {'type': '01;05', 'amount': '70.00;21.20'},
#  {'type': '01;05', 'amount': '140.00;141.80'},
#  {'type': '01;05', 'amount': '50.00;145.20'},
#  {'type': '01;05', 'amount': '25.50;82.43'},
#  {'type': '01;05', 'amount': '100.00;24.25'},
#  {'type': '01;05', 'amount': '50.00;33.00'},
#  {'type': '04;05', 'amount': '49.00;57.90'},
#  {'type': '01;05', 'amount': '30.00;28.50'},
#  {'type': '17;05', 'amount': '50.00;9.60'},
#  {'type': '01;05', 'amount': '15.00;10.40'},
#  {'type': '01;05', 'amount': '100.00;58.58'},
#  {'type': '01;04', 'amount': '181.00;6.55'},
#  {'type': '01;05', 'amount': '40.00;5.50'},
#  {'type': '01;05', 'amount': '50.00;292.97'},
#  {'type': '01;05', 'amount': '20.00;35.50'},
#  {'type': '01;05', 'amount': '50.00;28.02'},
#  {'type': '01;05', 'amount': '20.00;28.00'},
#  {'type': '04;05', 'amount': '230.00;97.90'},
#  {'type': '01;05', 'amount': '84.00;4.00'},
#  {'type': '05;01', 'amount': '30.00;1.30'},
#  {'type': '01;05', 'amount': '50.00;28.30'},
#  {'type': '01;05', 'amount': '30.00;20.00'},
#  {'type': '01;05', 'amount': '20.00;44.35'},
#  {'type': '01;05', 'amount': '110.00;150.50'},
#  {'type': '01;05', 'amount': '2.40;40.00'},
#  {'type': '01;05', 'amount': '100.00;54.00'},
#  {'type': '01;05', 'amount': '60.00;47.47'},
#  {'type': '01;05', 'amount': '38.00;59.90'},
#  {'type': '01;05', 'amount': '30.00;3.80'},
#  {'type': '01;05', 'amount': '20.00;18.38'},
#  {'type': '01;05', 'amount': '2.00;40.00'},
#  {'type': '01;05', 'amount': '70.00;39.40'},
#  {'type': '01;05', 'amount': '6.00;27.10'},
#  {'type': '01;04', 'amount': '0.50;13.00'},
#  {'type': '01;05', 'amount': '20.00;20.90'},
#  {'type': '01;05', 'amount': '50.00;49.20'},
#  {'type': '01;05', 'amount': '70.00;50.00'},
#  {'type': '01;05', 'amount': '50.00;38.10'},
#  {'type': '01;05', 'amount': '50.00;38.00'},
#  {'type': '01;05', 'amount': '100.00;53.70'},
#  {'type': '01;05', 'amount': '50.00;82.05'},
#  {'type': '01;05', 'amount': '10.00;8.48'},
#  {'type': '01;05', 'amount': '36.00;7.70'},
#  {'type': '01;05', 'amount': '25.00;25.00'},
#  {'type': '05;01', 'amount': '15.01;189.23'},
#  {'type': '01;05', 'amount': '100.00;158.60'},
#  {'type': '01;05', 'amount': '100.00;3.60'},
#  {'type': '01;05', 'amount': '51.40;30.00'},
#  {'type': '01;05', 'amount': '20.00;100.00'},
#  {'type': '01;05', 'amount': '40.00;10.60'},
#  {'type': '01;05', 'amount': '2.50;109.02'},
#  {'type': '01;05', 'amount': '14.50;95.95'},
#  {'type': '01;05', 'amount': '46.70;106.15'},
#  {'type': '01;05', 'amount': '160.00;37.13'},
#  {'type': '01;05', 'amount': '100.00;46.11'},
#  {'type': '01;05', 'amount': '100.00;4.80'},
#  {'type': '01;05', 'amount': '50.00;106.00'},
#  {'type': '01;05', 'amount': '100.00;137.11'},
#  {'type': '01;05', 'amount': '11.50;290.00'},
#  {'type': '17;05', 'amount': '54.00;50.00'},
#  {'type': '01;05', 'amount': '150.00;8.72'},
#  {'type': '01;05', 'amount': '50.00;109.00'},
#  {'type': '01;05', 'amount': '2.80;63.75'},
#  {'type': '01;05', 'amount': '100.00;37.68'},
#  {'type': '01;05', 'amount': '118.00;11.10'},
#  {'type': '01;05', 'amount': '70.00;28.43'},
#  {'type': '01;05', 'amount': '200.00;16.30'},
#  {'type': '01;05', 'amount': '150.00;22.65'},
#  {'type': '01;05', 'amount': '30.00;6.25'},
#  {'type': '01;05', 'amount': '58.00;31.00'},
#  {'type': '01;05', 'amount': '2.10;60.00'},
#  {'type': '01;05', 'amount': '64.00;9.10'},
#  {'type': '01;05', 'amount': '50.00;25.00'},
#  {'type': '01;05', 'amount': '120.00;42.60'},
#  {'type': '01;05', 'amount': '50.00;9.25'},
#  {'type': '01;05', 'amount': '100.00;41.10'},
#  {'type': '01;05', 'amount': '22.00;11.00'},
#  {'type': '01;05', 'amount': '100.00;67.00'},
#  {'type': '01;05', 'amount': '50.00;12.40'},
#  {'type': '01;05', 'amount': '30.00;1.00'},
#  {'type': '01;05', 'amount': '0.70;40.00'},
#  {'type': '01;05', 'amount': '85.00;16.00'},
#  {'type': '01;05', 'amount': '100.00;233.75'},
#  {'type': '01;05', 'amount': '75.00;76.00'},
#  {'type': '01;05', 'amount': '50.00;166.09'},
#  {'type': '05;01', 'amount': '15.40;150.00'},
#  {'type': '01;05', 'amount': '180.00;4.60'},
#  {'type': '01;05', 'amount': '50.00;79.85'},
#  {'type': '01;05', 'amount': '20.00;11.18'},
#  {'type': '01;05', 'amount': '100.00;13.00'},
#  {'type': '01;05', 'amount': '20.00;29.90'},
#  {'type': '01;05', 'amount': '150.00;87.32'},
#  {'type': '01;05', 'amount': '100.00;162.00'},
#  {'type': '01;05', 'amount': '50.00;44.20'},
#  {'type': '01;05', 'amount': '50.00;16.20'},
#  {'type': '01;05', 'amount': '86.00;23.50'},
#  {'type': '01;05', 'amount': '40.00;10.00'},
#  {'type': '01;05', 'amount': '50.00;68.20'},
#  {'type': '01;05', 'amount': '33.00;3.47'},
#  {'type': '01;05', 'amount': '50.00;17.50'},
#  {'type': '01;05', 'amount': '100.00;19.63'},
#  {'type': '05;01', 'amount': '87.00;137.36'},
#  {'type': '01;05', 'amount': '50.00;222.40'},
#  {'type': '04;01', 'amount': '45.00;2.50'},
#  {'type': '01;05', 'amount': '50.00;41.05'},
#  {'type': '01;03', 'amount': '23.00;24.00'},
#  {'type': '01;05', 'amount': '4.00;9.00'},
#  {'type': '01;05', 'amount': '0.70;50.00'},
#  {'type': '03;04;01', 'amount': '170.00;60.00;79.70'},
#  {'type': '01;05', 'amount': '50.00;1.00'},
#  {'type': '01;05', 'amount': '40.00;18.00'},
#  {'type': '01;05', 'amount': '20.00;7.50'},
#  {'type': '05;01', 'amount': '1.00;42.00'},
#  {'type': '01;05', 'amount': '80.00;8.95'},
#  {'type': '01;05', 'amount': '3.60;24.00'},
#  {'type': '01;05', 'amount': '150.00;9.98'},
#  {'type': '01;05', 'amount': '20.00;11.50'},
#  {'type': '03;01', 'amount': '65.00;67.00'},
#  {'type': '01;05', 'amount': '5.45;40.00'},
#  {'type': '01;05', 'amount': '70.00;74.90'},
#  {'type': '01;05', 'amount': '100.00;251.50'},
#  {'type': '01;05', 'amount': '40.00;9.00'},
#  {'type': '01;05', 'amount': '10.00;46.30'},
#  {'type': '01;05', 'amount': '1.30;17.90'},
#  {'type': '01;05', 'amount': '50.00;10.20'},
#  {'type': '01;05', 'amount': '10.00;33.50'},
#  {'type': '01;05', 'amount': '80.00;3.10'},
#  {'type': '01;05', 'amount': '15.00;19.60'},
#  {'type': '01;05', 'amount': '50.00;49.70'},
#  {'type': '05;17;03', 'amount': '1.00;1.00;1.00'}]

# %% [markdown]
# Se a célula anterior retornou `0`, conseguiremos processar as informações de pagamento de todos os documentos.
#
# Agora só faltam a **data de emissão** e os **números de identificação** das notas de venda:

# %%
def get_key(xml: dict):
    try:
        return xml["nfeProc"]["NFe"]["infNFe"]["@Id"][3:]
    except KeyError:
        return xml["NFe"]["infNFe"]["@Id"][3:]

incs = []
for nf in nfes:
    with open(nf) as doc:
        xmlelem = xmltodict.parse(doc.read())
    try:
        _ = get_key(xmlelem)
    except KeyError:
        incs.append(xmlelem)

len(incs)
# Out:
# 0

# %% [markdown]
# Se a célula acima retornou `0`, significa que agora só precisamos fazer o *parsing* das **datas de emissão**:

# %%
def get_dt(xml: dict):
    try:
        return xml["nfeProc"]["NFe"]["infNFe"]["ide"]["dhEmi"]
    except KeyError:
        return xml["NFe"]["infNFe"]["ide"]["dhEmi"]

incs = []
for nf in nfes:
    with open(nf) as doc:
        xmlelem = xmltodict.parse(doc.read())
    try:
        _ = get_dt(xmlelem)
    except KeyError:
        incs.append(xmlelem)

len(incs)
# Out:
# 0

# %%
with open(nfes[5000]) as doc:
    xmlelem = xmltodict.parse(doc.read())

# %%
def get_total(xml: dict):
    try:
        total = xml["nfeProc"]["NFe"]["infNFe"]["total"]["ICMSTot"]
    except KeyError:
        total = xml["NFe"]["infNFe"]["total"]["ICMSTot"]
    
    products = None
    if "vNF" in total.keys():
        products = total["vNF"]
    
    discount = None
    if "vDesc" in total.keys():
        discount = total["vDesc"]

    taxes = None
    if "vTotTrib" in total.keys():
        taxes = total["vTotTrib"]

    return {
        "products": products,
        "discount": discount,
        "taxes": taxes}


incs = []
for nf in nfes:
    with open(nf) as doc:
        xmlelem = xmltodict.parse(doc.read())
    try:
        _ = get_total(xmlelem)
    except KeyError:
        incs.append(xmlelem)

len(incs)
# Out:
# 0

# %%
def parse_(xml: dict):
    key = get_key(xml)
    dt = get_dt(xml)
    pay = get_pay(xml)
    total = get_total(xml)

    return {"key":key, "dt":dt, "pay":pay, "total": total}

parsed = []
incs = []
for nf in nfes:
    with open(nf) as doc:
        xmlelem = xmltodict.parse(doc.read())
    try:
        vals = parse_(xml=xmlelem)
        parsed.append(vals)
    except KeyError:
        incs.append(xmlelem)

# %%
[a for a in parsed if a["total"]["taxes"] is not None]
# Out:
# []

# %%
with open(nfes[-1]) as doc:
    xmlelem = xmltodict.parse(doc.read())

# %%
parsed = []
for nf in nfes:
    dte = datetime.strptime(xmlelem["nfeProc"]["NFe"]["infNFe"]["ide"]["dhEmi"], "%Y-%m-%dT%H:%M:%S%z")
    print(dte, end="\r")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 3
#       1 parsed = []
#       2 for nf in nfes:
# ----> 3     dte = datetime.strptime(xmlelem["nfeProc"]["NFe"]["infNFe"]["ide"]["dhEmi"], "%Y-%m-%dT%H:%M:%S%z")
#       4     print(dte, end="\r")
#
# KeyError: 'nfeProc'
