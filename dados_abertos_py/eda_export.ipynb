# %%
import pandas as pd
import numpy as np
from DadosAbertosBrasil import ibge, ipea, bacen

# %%
help(ibge.lista_tabelas)
# Out:
# Help on function lista_tabelas in module DadosAbertosBrasil._ibge.sidra:
#
# lista_tabelas(contendo: Optional[str] = None, excluindo: Optional[str] = None, assunto: Union[int, str, NoneType] = None, classificacao: Union[int, str, NoneType] = None, periodo: Union[dict, str, NoneType] = None, periodicidade: Union[int, str, NoneType] = None, nivel: Union[int, str, NoneType] = None, pesquisa: Optional[str] = None, index: bool = False) -> pandas.core.frame.DataFrame
#     Lista de tabelas disponíveis no SIDRA.
#
#     Parameters
#     ----------
#     contendo : str, optional
#         Termo que deve estar contido no nome ou no comentário da série.
#     excluindo : str | list[str], optional
#         Termo ou lista de termos que não pode aparecer no nome da série.
#         Sobrepõe o argumento `contendo`.
#     assunto : str | int, optional
#         Busque apenas as tabelas referentes ao assunto desejado.
#         Os assuntos são identificados por um código numérico e podem ser
# ...

# %%
ibge.referencias('c')
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467 try:
# --> 468     self._validate_conn(conn)
#     469 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
# ...
